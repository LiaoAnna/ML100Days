# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w=3
b=0.5

x_lin=np.linspace(0,100,101)
y=(x_lin+np.random.randn(101)*5)*w+b
plt.plot(x_lin, y,"b.",label="datapoints")
plt.title("Assume we have data points")
plt.legend(loc=2)
plt.show()

# %%
y_hat=x_lin*w+b
plt.plot(x_lin,y,"b",label="data")
plt.plot(x_lin,y_hat,"r-",label="prediction")
plt.title("assume we have data points(and the prediction)")
plt.legend(loc=2)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
def mean_absolute_error(y,yp):
      #y:實際值 yp:預測值
    mae=MAE=sum(abs(y-yp))/len(y)
    return mae
MAE=mean_absolute_error(y,y_hat)
print("The Mean absolute error is %.3f"  % (MAE))
# Out:
# The Mean absolute error is 11.007

# %%
def mean_squated_error(y,yp):
    x=(y-yp)**2
    squ=SQU=sum(abs(x))/len(y)
    
    return squ
squ=mean_squated_error(y,y_hat)
print("The Mean squated error is %.3f"  % (squ))
# Out:
# The Mean squated error is 197.910

# %%
https://www.kaggle.com/c/nlp-getting-started/overview
問題一：為什麼這個問題重要？(Why it is important?)
1.增加新聞可信度
2.減少圖文不符的狀況
問題二：資料從何而來？(Where do data come from?)
1.來自推特
問題三：資料的型態是什麼？(What are they?)
1.非結構化(主要以文字圖片為主)
問題四：我們可以回答什麼問題 ？問題 : 指標(What is our goal?)
圖片與文字的相關程度

# %%
1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
   提升業績:每日載客量增加
   增加載客量的方法(提升服務品質、減少顧客乘車時間)

2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
   減少顧客乘車時間:蒐集顧客乘車資訊>>得知顧客的乘車時間與地點，預估行程時間。
                                透過車隊的記錄器搜集資料
               蒐集塞車的路段>>影響路經規劃
                              交通部提供的資料
                    
3. 蒐集而來的資料型態為何
   結構化資料(數值)  

4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
   透過避免塞車路段來減少顧客乘車的時間是否真的符合現實狀況
   利用多階段車流模式之相關公式，推估所花費的時間，再利用實際測量，來計算真正所花費的時間，
   比較兩者之間的差異
